# %%
print(2**3)
print(8/2)
print(8//2)
# Out:
# 8
# 4.0
# 4

# %%
# OPerator Overlaoding
'ved' + 'ant'
# Out:
# 'vedant'

# %%
import math

print(math.pow(2,3))

print(math.floor(3.9))
print(math.floor(3.1))
print(math.floor(-3.1))
print(math.floor(-3.9))
#  the box operator [] also known as floor
# Out:
# 8.0
# 3
# 3
# -4
# -4

# %%
print(math.trunc(2.8))
print(math.trunc(-4.1))
print(math.trunc(-4.9))
print(math.trunc(2.2))
# trunc gives us value which is closer to 0 on number line
# Out:
# 2
# -4
# -4
# 2

# %%
print(hex(64))
print(oct(64))
print(bin(64))
# Out:
# 0x40
# 0o100
# 0b1000000

# %% [markdown]
# ## Decimal

# %%
print(0.1 + 0.1 + 0.1)
print(0.1 + 0.1 + 0.1 - 0.3)

from decimal import Decimal
print(Decimal(0.1) + Decimal(0.1) +Decimal(0.1))
print(Decimal('0.1') + Decimal('0.1') +Decimal('0.1'))
print(Decimal('0.1') + Decimal('0.1') +Decimal('0.1') - Decimal('0.3'))
# Out:
# 0.30000000000000004
# 5.551115123125783e-17
# 0.3000000000000000166533453694
# 0.3
# 0.0

# %% [markdown]
# ## Fraction

# %%
from fractions import Fraction
print(Fraction(2/7) + Fraction(5/7))
print(Fraction('2/7') + Fraction('5/7'))
print((2/7) + (5/7))
# Out:
# 1
# 1
# 1.0

# %% [markdown]
# ## Sets

# %%
set = {1,2,3,4}
print(set & {1,5}) # intersection
print(set |{1,5,9}) # intersection
# Out:
# {1}
# {1, 2, 3, 4, 5, 9}

# %% [markdown]
# ## Booleans

# %%
print(True + 2)
print(False - 2)
# Out:
# 3
# -2
