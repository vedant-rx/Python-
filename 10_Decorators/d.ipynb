# %% [markdown]
# ## Decorator to measure the time taken by a function to execute

# %%
import time

def timer(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print(f"{func.__name__} took {end-start} time to execute")
        return result
    return wrapper

@timer #this creates a decorator ..... what happens is whenever the exe function is called, it will go through the timer function
def exe(n):
    time.sleep(n)
exe(2)
exe(3)
# Out:
# exe took 2.001272201538086 time to execute
# exe took 3.004905939102173 time to execute

# %% [markdown]
# ## Create a decorator to return the function anme and its arguments evrytime the functuon is called

# %%
def bada(func):
    def wrapper(*args):
        print(f"the name of the function is {func.__name__} and its contents are {args}")
        return func(*args)
    return wrapper

@bada
def hi(name,age):
    print(name,age)

hi("ved", 5)
# Out:
# the name of the function is hi and its contents are ('ved', 5)
# ved 5

# %% [markdown]
# ## Implement a decorator to cache the results of a function so that if the function is called with the same arguments again, it returns the cached result instead of recomputing it.

# %%
import time

def cache(func):
    cache_value={}
    print(cache_value)
    def wrapper(*args):
        if args in cache_value:
            return cache_value[args]
        result = func(*args)
        cache_value[args] = result
        return result
    return wrapper

@cache
def long_running_function(a, b):
    time.sleep(4)
    return a+b

print(long_running_function(2,3)) #takes 4 sec.     4
print(long_running_function(3,3)) #takes next 4 sec. 8
print(long_running_function(2,3)) # this gets printed immediately.  8
# Out:
# {}
# 5
# 6
# 5
